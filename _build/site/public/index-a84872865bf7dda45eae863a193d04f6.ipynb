# %% [markdown]
# # Programmering for lærere

# %% [markdown]
# På denne nettsiden vil vi etterhvert legge ut aktiviteter og opplegg som handler om programmering i skolen.
#
# Disse nettsidene er ikke ment som kurs i grunnleggende programmering, men heller som en samling av kortere eller lengre eksempler på hvordan programmering kan brukes til undervisning og utforsking i matematikk og naturfag.
#
# De forskjellige aktivitetene har forskjellig didaktisk tilnærming, men ett viktig poeng er å lære seg å kunne lese kode og kunne koble koding til konkrete aktiviteter i de forskjellige fagene, matematikk og naturfag, og hvordan koding kan forsterke faglig forståelse og hvordan koding kan brukes til utforsking.
#
# Av:
# * Viggo T. Andersen - USN
# * Sigurd Rage - USN

# %% [markdown]
# # Didaktisk tilnærming
# Vi legger mer vekt på koblingen mellom sekvensforståelse, språk og logikk enn det å kunne bruke all mulige tekniske muligheter i programmering. Gjennom arbeid med eksemplene vil man lære seg teknikker og metoder for å kunne bruke programmering til å forsterke eller utforske fag. I eksemplene som er lagt opp til arbeid i par kan vi trekke inn PRIMM-metoden (Sue Sentance), men det er også mulig å jobbe med eksemplene alene (Use-Modify-Create). For eksempel, i aktiviteten hvor man lager funksjontabeller og
