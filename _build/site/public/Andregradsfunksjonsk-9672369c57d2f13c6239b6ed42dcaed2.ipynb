# %% [markdown]
# # Enkel funksjonsanalyse av andregradsfunksjoner

# %% [markdown]
# I denne aktiviteten skal du prøve å lage en kalkulator for å regne ut nullpunkter og ekstremalpunkt for andregradfunksjoner i Python

# %% [markdown]
# ## Nullpunkter
# Her er et forslag til pseudokode for å finne nullpunkter i en andregradsfunksjon:
# 1. Lag 3 variabler for a, b og c som i det generelle andregradsuttrykket $ax^2+bx+c$
# 2. Sjekk om funksjonen faktisk har nullpunkter (er $b^2 < 4ac$ ?)
# 3. Hvis den har nullpunkter, bruk løsningsformelen: $x = \frac{-b \pm \sqrt{b^2-4ac}}{2a}$ til å finne nullpunktene
# 4. Bruk formelen for symmetrilinjen til andregradsfunksjonen og finn ekstremalpunktet: $x=-\frac{b}{2a}$
# 5. Bruk fortegnet til a til å bestemme om dette er et topp- eller bunnpunkt, og skriv ut koordinatet på formen (x,y)
#
# Ikke lov til å sjekke fasit før dere har prøvd!!!

# %%
a = 1
b = 0
