# %% [markdown]
# # Matematikk - introduksjon

# %% [markdown]
# * Aktiviteter og opplegg om programmering med en klar kobling til matematikkfaget
# * Begrunnelse om hvorfor vi ikke egentlig har lyst til å lage rene programmeringsaktivteter
