# %% [markdown]
# # Grunnleggende Python

# %% [markdown]
# På denne siden skal vi se på enkle og grunnleggende kodelementer i Pyhton, vi skal se på:
# * Variabler
# * Inndata (input) og utdata (print)
# * Operasjoner, addisjon, subtraksjon, multiplikasjon, divisjon
# * Sammenligninger (ekvivalens, mindre- og større enn)

# %% [markdown]
# Alle kodeeksemplene på denne siden kan kopieres og limes inn i din eget Pyhton-editor (f.eks Thonny eller Trinket) slik at du kan teste de selv, og eventuelt leke litt med eksemplene og endre på verdier og slike ting. Hver gang du begynner med et nytt eksempel må du slette koden fra forrige, eller lage en ny fil eventuelt.

# %% [markdown]
# Trinket finner du her: https://trinket.strivemath.org/python3

# %% [markdown]
# ## Variabler og skrive ut til skjerm (print)

# %% [markdown]
# Programmet nedenfor lager en tallvariabel og en tekstvariabel og skriver ut innholdet på forskjellige måter. Hvordan tror du det fungerer? (PS Linjene som begynner med # er kommentarer til koden ment for å forklare underveis, disse linjene er IKKE en del av programmet!). Resultatet av programmet ser du nedenfor koden.

# %% [markdown]
# ```{note} Bruk av = i programmering
# Vær obs på at likhetstegnet = ikke er helt det samme i programmering som i matematikk. I programmering bruker man = som en tildelingsoperator. Dette er viktig å kunne, siden det kan forsterke en vanlig misoppfatning om likhetstegnet i matematikk. Se lenger ned på siden for hvordan man bruker ekvivalens i programmering.
# ```

# %%
#vi skriver inn en verdi for x 
x = 10 
#vi skriver ut verdien til x  
print(x) 
#tar med tekst i tillegg til verdien av x 
print("x er lik", x) 
#skriver ut navnet ditt 
print("Ola Nordmann") 
#Definerer ditt navn til å være en variabel vi kaller dittnavn 
dittnavn = "Ola Nordmann" 
#skriver ut første bokstav av navnet ditt 
print(dittnavn[0]) 
#Tar ut deler av navnet fra bokstav 4 til 12 
print(dittnavn[4:12])
# Out:
# 10
# x er lik 10
# Ola Nordmann
# O
# Nordmann

# %% [markdown]
# ```{tip} Oppgave
# Kopier denne koden til din egen Python-editor, og sjekk selv. Prøv å endre på verdiene av variablene x og dittnavn og se hva som skjer.
# ```

# %% [markdown]
# ## Regneoperasjoner

# %% [markdown]
# Vi lager et nytt program, her skal vi undersøke hvordan vi kan addere, subtrahere, multiplisere og dividere med operatorer i Python.
#
# Vi:
# * Definerer to variabler a og b
# * Vi adderer disse og skriver ut svaret
# * Vi gjentar dette for subtraksjon, multiplikasjon og divisjon

# %%
#definerer variablene a og b 
a = 4 
b = 8 
 
#summerer a og b og skriver ut summen 
sum = a + b 
print("Summen er",sum) 
 
#subtraherer a fra b og skriver ut summen 
sub = b - a 
print("Differansen er",sub) 
 
#dividerer a og b og skriver ut summen 
div = a/b 
print("Kvotient er", div) 
 
#multipliserer a og b og skriver ut summen 
mult = a*b 
print("Produktet er", mult)
# Out:
# Summen er 12
# Differansen er 4
# Kvotient er 0.5
# Produktet er 32

# %% [markdown]
# ```{tip} Oppgave
# Kopier denne koden til din egen Python-editor, og sjekk selv. Prøv å endre på verdiene av variablene a og b og se hva som skjer!
# ```

# %% [markdown]
# ## Hente inn verdier fra brukeren

# %% [markdown]
# I eksemplene over er verdiene til variablene definert i selve koden. Det går også an å la den som bruker programmet skrive inn verdier når koden kjøres. I eksempelet under lar vi brukeren bestemme verdiene til a og b ved hjelp av kommandoen input().

# %% [markdown]
# ```{note} Datatyper
# I Pyhton er kan variabler både være tallverdier og tekst, men python kan ikke gjøre beregninger på tekst, derfor er inputkommandoen "nøstet" inne i en int() kommando som gjør tekstverdien til svaret om til et heltall. Altså hvis bruker skriver verdien(teksten) "4" så gjør int() kommandoen verdien om til tallet 4. Vi skal se nærmere på datatyper senere!
# ```

# %%
#importerer to valgfrie variable a og b 
a = int(input("Hvilket heltall er a?")) 
b = int(input("Hvilket heltall er b?")) 
#summerer a og b og skriver ut svaret 
summen = a + b 
print("Summen er",summen) 
#subtraherer a fra b og skriver ut svaret 
sub = b - a 
print("Differansen er",sub) 
#dividerer a og b og skriver ut svaret 
div = a/b 
print("Kvotient er", div) 
#multipliserer a og b og skriver ut svaret 
mult = a*b 
print("Produktet er", mult)
# Out:
# Hvilket heltall er a? 12
# Hvilket heltall er b? 10
# Summen er 22
# Differansen er -2
# Kvotient er 1.2
# Produktet er 120

# %% [markdown]
# ```{tip} Oppgave
# Kopier denne koden til din egen Python-editor, og sjekk selv. Nå kan du skrive inn forskjellige verdier for a og b hver gang koden kjøres!
# ```

# %% [markdown]
# ## Utskrifter

# %% [markdown]
# Vi har allerede brukt utskriftsfunksjonen print() i eksemplene over. Det er mange måter å sette sammen utskrifter på, i eksemplet under skal vi se på 2 forskjellige måter. Legg merke til at den første metoden er enklest. I den andre metoden må vi endre tallverdien til div til en tekst, og vi får ikke automatisk mellomrom.

# %%
# vi tar inn to verdier 
a = 5 
b = 7 

#vi dividerer verdiene og skriver ut resultatet 
div = a/b 

# Metode 1: kommaseparaert
print("divisor er lik", div)

# Metode 2: satt sammen med +
print("divisor er lik " + str(div))
# Out:
# divisor er lik 0.7142857142857143
# divisor er lik 0.7142857142857143

# %% [markdown]
# ```{tip} Oppgave
# Kopier denne koden til din egen Python-editor, og sjekk selv.
# ```

# %% [markdown]
# # Sammenligninger i programmering

# %% [markdown]
# Nå har vi endelig kommet til hvordan programmering forholder seg til matematisk likhet. I logikk kalles dette for betingelser, og vi kan bruke betingelser til å la programkoden ta avgjørelser, mer om dette i neste aktivitet I Python bruker vi følgende operatorer for sammenligning av to verdier:
# :::{table} Sammenlingingsoperatorer
# :label: table
# :align: center
# | Operator | Forklaring |
# | --- | --- |
# | == | tester for likhet |
# | \< | tester for ulikhet (mindre enn) |
# | \> |tester for ulikhet (større enn) |
# | <= | tester for ulikhet (mindre enn ELLER lik) |
# | \>= |tester for ulikhet (større enn ELLER lik) |
# | != | tester for ikke-lik |
# :::
#
# Resulatet av en slik sammenligningstest i programkode blir enten sant (True) eller usant (False). Se på følgende kode:

# %%
#tester om et tall er lik 5 
b = 10 
test = (b==5) 
print("Er", b, "lik 5?", test)
# Out:
# Er 10 lik 5? False

# %% [markdown]
# ```{tip} Oppgave
# Kopier denne koden til din egen Python-editor, og sjekk selv. Prøv å endre verdien for b til 5 og se hva som skjer!
# ```

# %% [markdown]
# I matematikk, for eksempel når gjør beregninger eller løser likninger så er vi ofte interessert i ekvivalens som riktig svar, eller løsning på en likning. I programmering er det litt mer til dette, vi bruker sammenligningsoperatorer for å se om ting er sanne eller usanne istedet.
#
# I kodeeksemplet under er det brukt flere av disse sammenligningsoperatorene

# %%
#tar inn to tall og tester om de er like, ulike, større eller mindre osv
a = 1
b = 2
#tester om tall 1 er større enn tall 2 
test1 = (a>b) 
print("Er", a, "større enn", b, "?", test1)
#tester om tall 1 er mindre enn tall 2 
test2 = (a<b) 
print("Er", a, "mindre enn", b, "?", test2)
#tester om tall 1 er lik tall 2 
test3 = (a==b) 
print("Er", a, "lik", b, "?", test3)
# Out:
# Er 1 større enn 2 ? False
# Er 1 mindre enn 2 ? True
# Er 1 lik 2 ? False

# %%
```{tip} Oppgave
Kopier denne koden til din egen Python-editor, og sjekk selv. Prøv å endre verdien for b til 5 og se hva som skjer!
```

# %% [markdown]
# Mer om sammenligninger og betingelser på denne siden: https://code-usn.github.io/usnprogrammering/likheter-ulikheter-betingelser/
