# %% [markdown]
# # Gjennomsnitt, varians og standardavvik for EN terning

# %% [markdown]
# Nedenfor finner du starten på et program som skal regne ut varians og standardavvik. Programmet tar utgangspunktet i at du kaster en 6-sidet terning 10 ganger (disse verdiene kan endres).
#
# For å holde rede på summen av terningen og variansen er det laget to tellevariabler som oppdateres etter hvert terningkast i for-løkken.
#
# Din oppgave er å legge til kode som regner ut variansen og gjennomsnittet for forsøket, og å undersøke hva som skjer med disse verdiene hvis du endrer på antall forsøk!

# %% [markdown]
# ```{hint} Tips: Hvordan regne ut variansen!
# :class: dropdown
# 1. Regne ut forventningsverdi.
# 2. Regne ut forskjellene mellom gjennomsnittet og hvert av tallene.
# 3. Kvadrere forskjellene.
# 4. Summere kvadratene av forskjellene.
# 5. Dividere summen med det totale antallet observasjoner.
#
# PS! Noe av dette er allerede gjort i koden nedenfor.
# ```

# %% [markdown]
# ```{code} python
# :linenos:
# # Importerer bibliotek for tilfeldighet
# import random as rnd
#
# # Antall sider på terninger
# sider = 6
#
# # Antall forsøk
# antall_forsøk = 10
#
# forventning = (sider+1)/2
#
# # variabler for å huske summer i sløyfen
# variansteller = 0
# summen = 0
#
# for i in range(antall_forsøk):
#     terning = rnd.randint(1, sider)
#     print("kast " + str(i+1) + ": " + str(terning) ) #bør fjernes ved høyt antall kast
#     variansteller = #Her må du lage en formel for å regne ut variansen for hvert delforsøk
#     summen = summen + terning
#
# # Her kan du lage kode for å regne ut:
# # * gjennomsnitt
# # * varians og standardavvik
# # * skriv ut resultatet med print
#
# # Eksempel på kode for utskrift
# print("Summen er:", summen)
# ```

# %% [markdown]
# ```{tip} Oppgave
# 1. Les koden sammen med en partner og bli enige om hva dere tror koden gjør/ hvordan den fungerer.
# 2. Skriv ferdig koden i linje 19 for å regne ut variansen for hvert delforsøk
# 3. Etter for-sløyfen, beregn gjennomsnitt, regn ferdig variansen. Regn ut standardavviket.
# 4. Skriv disse verdiene ut til skjerm, se linje 28 for eksempel på hvordan dette kan gjøres
# 5. Bonusoppgave: Kan du utvide programmet slik at vi kan se på forsøk med to eller flere terninger (krever nøstede sløyfer)?
# ```
