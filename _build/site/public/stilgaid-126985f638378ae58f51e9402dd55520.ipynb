# %% [markdown]
# # Stilgaid

# %% [markdown]
# ## overskrift 2

# %% [markdown]
# ### overskrift 3 (skal vi bruke det?)

# %% [markdown]
# Vanlig tekst. Matteformel inline: $f(x)=\frac{x-2}{x+4}$
#
# Nytt avsnitt krever dobbelt linjeskift.
# Matteformel sentrert og nummerert:
# $$ f(x) = x^2-4x-4 $$

# %% [markdown]
# Vanlig pythoncelle fra notebook med output

# %%
import math

a = 3
b = 4
c = math.sqrt(a**2+b**2)
print(c)
# Out:
# 5.0

# %% [markdown]
# Formatert kode som ikke skal kjøres med resultat:

# %% [markdown]
# ```{code}python
# import math
#
# a = 3
# b = 4
# c = math.sqrt(a**2+b**2)
# print(c)
# ```

# %% [markdown]
# Formatert kode med merkelapp og caption

# %% [markdown]
# ```{code} python
# :label: Pythagoraskalkulator
# :caption: Regner ut hypotenusen fra katetenes lengder
# import math
#
# a = 3
# b = 4
# c = math.sqrt(a**2+b**2)
# print(c)
# ```

# %% [markdown]
# Formatert kode med linjenummer utheving av linjer:

# %% [markdown]
# ```{code} python
# :linenos:
# :emphasize-lines: 5,6
# import math
#
# a = 3
# b = 4
# c = math.sqrt(a**2+b**2)
# print(c)
# ```

# %% [markdown]
# Eksempel med "inline" kode: `c = math.sqrt(a**2+b**2)`.{python}

# %% [markdown]
# Oppgave med admonition tip

# %% [markdown]
# ```{tip} Tittel
# Her kommer oppgaven
# ```

# %% [markdown]
# Løsning med adminition hint og dropdown

# %% [markdown]
# ```{hint} Tittlel, feks løsningsforslag
# :class: dropdown
# Her kommer løsningsforslag
# ```

# %% [markdown]
# Løsningsforslag med kode (NB legg merke til at ytre blokk bruker ```` og indre bruker ```

# %% [markdown]
# ````{tip} Løsning med kode
# :class: dropdown
# Innledende tekst
# ```{code}python
# import math
#
# a = 3
# b = 4
# c = math.sqrt(a**2+b**2)
# print(c)
# ```
# Jeg kan skrive her også!
# ````
