# %% [markdown]
# # Enkel funksjonsanalyse av andregradsfunksjoner

# %% [markdown]
# ## TODO
# * strukurere aktiviteten om slik vi gjorde på samling
# * koble aktiviteten til matematikk
# * hvordan programmering av dette kan forsterke enkel funksjonsanalyse fra MG2MA2
# * Gjøre et poeng ut av arbeidsformen, hvordan man utvikler koden steg for steg fra pseudokode

# %% [markdown]
# # Utvikling av programmet
# I denne aktiviteten skal du prøve å lage en kalkulator for å regne ut nullpunkter og symmetrilnje for andregradfunksjoner i Python. Du må bruke variabler og beregninger og betingelser (IF-ELIF-ELSE) for å få dette til! Vi skal utvikle koden steg for steg

# %% [markdown]
# ## Symmetri og ekstremalpunkt
# Her er et forslag til pseudokode for å finne symmetrilinjen og ekstremalpunktet i en andregradsfunksjon:
# 1. Lag 3 variabler for a, b og c som i det generelle andregradsuttrykket $ax^2+bx+c$
# 3. Bruk formelen for symmetrilinjen til andregradsfunksjonen og finn ekstremalpunktet: $x=-\frac{b}{2a}$
# 4. Bruk fortegnet til a til å bestemme om dette er et topp- eller bunnpunkt
# 5. Skriv ut koordinatene på ekstremalpunktet
#
# Tips: Koeffisienten a i det generelle funksjonsuttrykket  $f(x)=ax^2+bx+c$ bestemmer om grafen har bunnpunkt eller toppunkt og lag en if-test som kan sjekke om a er større eller mindre enn null

# %% [markdown]
# ```{important} Steg 1
# Prøv å skrive koden som finner symmetrilinjen i ditt pythonprogram:
#
# Som eksempel kan du for eksempel bruke $f(x)=x^2-2x-3$, som gir a = 1, b = -2 og c = -3. Bruk gjerne Geogebra og plott funksjonen før du skriver koden.
# ```

# %% [markdown]
# ````{hint} Løsningsforslag
# :class: dropdown
# ```{code} python
# :linenos:
# a = 1
# b = -2
# c = -3
#
# x = (-b)/(2*a)
# print("Funksjonen har symmetrilinje for x = " + str(x))
# ```
# ````

# %% [markdown]
# ```{hint} Steg 2
# Bruk verdien til a til å bestemme om funksjonen har et topp- eller bunnpunkt:
# ```

# %% [markdown]
# ````{tip} Løsningsforslag
# :class: dropdown
# ```{code} python
# :linenos:
# :emphasize-lines: 10-17
# a = -1
# b = 0
# c = 4
#
# # Symmetrilinje:
# x = (-b)/(2*a)
#
# print("Vi har symmetrilinje for x = " + str(x))
#
# # Topp eller bunn?
#
# if a > 0:
#     print("Funksjonen har et bunnpunkt")
# elif a < 0:
#     print("Funksjonen har et toppunkt")
# else:
#     print("Funksjonen er ikke en andregradsfunksjon")
# ```
# ````

# %% [markdown]
# ```{hint} Steg 3
# Bruk x-verdien til symmetrilinjen og funksjonsuttrykket til å finne koordinatet til ekstremalpunktet:
# ```

# %% [markdown]
# ````{tip} Løsningsforslag
# :class: dropdown
# ```{code} python
# :linenos:
# :emphasize-lines: 19, 20, 21, 22, 23, 24, 25
# a = -1
# b = 0
# c = 4
#
# # Symmetrilinje:
# x = (-b)/(2*a)
#
# print("Vi har symmetrilinje for x = " + str(x))
#
# # Topp eller bunn?
#
# if a > 0:
#     print("Funksjonen har et bunnpunkt")
# elif a < 0:
#     print("Funksjonen har et toppunkt")
# else:
#     print("Funksjonen er ikke en andregradsfunksjon")
#
# # finner y-verdien til ekstremalpunktet
# y = a*x**2 + b*x + c
#
# print("x = " + str(x))
# print("y = " + str(y))
#
# # finner eventuelle nullpunkter:
# ```
# ````

# %% [markdown]
# ## Nullpunkter
# Forslag til pseudokode
# 1. Sjekk om funksjonen faktisk har nullpunkter (er $b^2 < 4ac$ ?). Andregradfunksjoner har enten 0, 1 eller 2 nullpunkter!
# 2. Hvis den har nullpunkter, bruk løsningsformelen: $x = \frac{-b \pm \sqrt{b^2-4ac}}{2a}$ til å finne nullpunktene

# %% [markdown]
# ````{tip} Forslag til pseudokode
# 1. Utvid programmet med kode som bruker en IF-test til å undersøke om funksjonen har 2, 1 eller ingen løsninger
# 2. På innsiden av disse IF-testene, bruk den generelle andregradsformelen til å regne ut nullpunkter dersom de eksisterer og skriv ut resultatet!
#
# Viktig: for å regne ut kvadratrøtter må du importere et bibliotek som heter math. Under finner du et eksempel på hvordan det fungerer. Import-setningen må stå øverst i koden din.
# ```{code} python
# import math
# kvadratrot = math.sqrt(16)
# print(kvadratrot)
# ```
# ````

# %% [markdown]
# ````{hint} Forslag til ferdig kode
# :class: dropdown
# ```{code} python
# :linenos:
# :emphasize-lines: 1, 2, 28 - 41
# # nødvendig bibliotek for å kunne ta kvadrat
# import math
#
# a = -1
# b = 0
# c = 4
#
# # Symmetrilinje:
# x = (-b)/(2*a)
#
# print("Vi har symmetrilinje for x = " + str(x))
#
# # Topp eller bunn?
#
# if a > 0:
#     print("Funksjonen har et bunnpunkt")
# elif a < 0:
#     print("Funksjonen har et toppunkt")
# else:
#     print("Funksjonen er ikke en andregradsfunksjon")
#
# # finner y-verdien til ekstremalpunktet
# y = a*x**2 + b*x + c
#
# print("x = " + str(x))
# print("y = " + str(y))
#
# # finner eventuelle nullpunkter:
#
# if b**2 > 4*a*c:
#     print("Funksjonen har to nullpunkter")
#     x = (-b - math.sqrt(b**2 - 4*a*c)) / (2*a)
#     print("x1 = ", str(x))
#     x = (-b + math.sqrt(b**2 - 4*a*c)) / (2*a)
#     print("x2 = ", str(x))
# elif b**2 == 4*a*c:
#     print("Funksjonen har ett nullpunkt")
#     x = (-b + math.sqrt(b**2 - 4*a*c)) / (2*a)
#     print("x = " + str(x))
# else:
#     print("Funksjonen har ingen nullpunkter")
# ```
# ````
