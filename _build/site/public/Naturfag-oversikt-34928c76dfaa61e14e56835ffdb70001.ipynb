# %% [markdown]
# # Naturfag - introduksjon

# %% [markdown]
# Her er en kommer oversikt over undersidene i seksjonen naturfag

# %% [markdown]
# # Todo
# * lage en side spenningsdeling og om hvordan sensorer virker (Elektrisitetslære)
# * Lage en side om input og output for Microbit (A/D og D/A)
# * Dele opp potteplantevanningsaktviteten - gjøre den mer utforskende.
# * Koble til mer didaktikk og algoritmisk tenking
