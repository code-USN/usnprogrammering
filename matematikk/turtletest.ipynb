# %%
from jupyturtle import Turtle

# Create a turtle instance
t = Turtle()

# Draw a square
for _ in range(4):
    t.forward(100)
    t.right(90)

# Show the drawing
t
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from jupyturtle import Turtle
#       3 # Create a turtle instance
#       4 t = Turtle()
#
# ModuleNotFoundError: No module named 'jupyturtle'
