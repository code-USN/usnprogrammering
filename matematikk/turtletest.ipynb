# %%
import jupyter.Turtle as t
t.forward(100)
t.right(90)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import jupyter.Turtle as t
#       2 t.forward(100)
#       3 t.right(90)
#
# ModuleNotFoundError: No module named 'jupyter.Turtle'; 'jupyter' is not a package
